# %%
# Loaded variable 'df' from URI: /Users/takahashi/LVNT/Avenue/Avenue_Dashboard/data/NetInflow/csv/net_inflow_raw.csv
import pandas as pd
df = pd.read_csv(r'/Users/takahashi/LVNT/Avenue/Avenue_Dashboard/backend/data/NetInflow/csv/net_inflow_raw.csv')

# %%
df.columns
# Out:
# Index(['net_inflow.date', 'net_inflow.created_date',
#        'net_inflow.settlement_date', 'net_inflow.client_cpf',
#        'net_inflow.client_email', 'net_inflow.client_name',
#        'net_inflow.foreign_finder_email', 'net_inflow.foreign_finder_code',
#        'net_inflow.foreign_finder_name', 'net_inflow.office_cnpj',
#        'net_inflow.office_name', 'net_inflow.kind', 'net_inflow.description',
#        'net_inflow.product_cusip', 'net_inflow.product_name',
#        'net_inflow.product_type', 'net_inflow.product_symbol',
#        'net_inflow.net_inflow_brl', 'net_inflow.net_inflow_usd'],
#       dtype='object')

# %%
df['net_inflow.client_name'].value_counts()
# Out:
# net_inflow.client_name
# Maria Cristina Guedes Jorge         170
# Agel Gustavo Turim Silverio          22
# EDUARDO SBOARINI                     21
# Rafael Neto Pacheco                  15
# BRUNA PAIVA SBOARINI                 14
# Leonardo Wascheck                     9
# Grace Mary Klein de Aquino            3
# Alexandre Yamashiro                   2
# Jones Antonio Pagno                   2
# MARIO ROSSI                           2
# Adilson Ferreira da Silva Junior      1
# Ricardo Hildebrand                    1
# sirlene bueno vaz                     1
# Marcos Antonio Medeiros               1
# Name: count, dtype: int64

# %%
# filter db by net_inflow.date = 30/01/2025 and shows all entries
df_filtered_30 = df[df['net_inflow.date'] == '2026-01-29']
df_filtered_30
# Out:
# Empty DataFrame
# Columns: [net_inflow.date, net_inflow.created_date, net_inflow.settlement_date, net_inflow.client_cpf, net_inflow.client_email, net_inflow.client_name, net_inflow.foreign_finder_email, net_inflow.foreign_finder_code, net_inflow.foreign_finder_name, net_inflow.office_cnpj, net_inflow.office_name, net_inflow.kind, net_inflow.description, net_inflow.product_cusip, net_inflow.product_name, net_inflow.product_type, net_inflow.product_symbol, net_inflow.net_inflow_brl, net_inflow.net_inflow_usd]
# Index: []
